# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8,6))

categories = ['Producto A', 'Producto B', 'Producto C']
sales = [120, 150, 90]

plt.bar(categories, sales, color='skyblue', label='Ventas mensuales')

plt.annotate('Maximo de ventas', 
            xy=('Producto B', 150),
            arrowprops=dict(facecolor= 'black', shrink= .05),
            xytext=('Producto C', 140))

plt.title('Ventas de productos en un mes')
plt.xlabel('Productos')
plt.ylabel('Ventas')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,6))

categories = ['Producto A', 'Producto B', 'Producto C']
sales = [120, 150, 90]

plt.barh(categories, sales, color='skyblue', label='Ventas mensuales')

# plt.annotate('Maximo de ventas', 
#             xy=('Producto B', 150),
#             arrowprops=dict(facecolor= 'black', shrink= .05),
#             xytext=('Producto C', 140))

plt.title('Ventas de productos en un mes')
plt.ylabel('Productos')
plt.xlabel('Ventas')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,6))

products = ['Producto A', 'Producto B', 'Producto C']
market_shape = [50, 35, 15]

plt.pie(market_shape, labels=products, 
        autopct='%1.1f%%', 
        startangle=140,
        colors=['gold', 'lightcoral', 'orange'])

plt.title('Participacion de Mercado por Producto')

plt.axis('equal')

plt.show()

# %%
# Datos para el ejercicio
np.random.seed(19680801)

# Cálculo de las barras polares de ángulo theta
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
colors = plt.cm.viridis(radii / 10.)

# Gráfico de barras en eje polor
ax = plt.subplot(projection='polar')
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)
plt.show()
